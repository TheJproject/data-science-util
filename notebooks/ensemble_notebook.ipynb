# %%
import pandas as pd
import tqdm

import numpy as np
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier,StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from omegaconf import OmegaConf

array = np.load(r"C:\Users\Jonah\OneDrive\Documents\Thesis\data-science-util\outputs\2023-03-13\16-32-56\array.npy")
cfg = OmegaConf.load(r'C:\Users\Jonah\OneDrive\Documents\Thesis\data-science-util\config.yaml')

# %%
mean_array = np.mean(array, axis=1)
print(mean_array)
# Print the mean array
arr_argmax = np.apply_along_axis(np.argmax, axis=0, arr=mean_array)

print(arr_argmax)
# Output
# map the predicted class index to the original label
label_map = {0: 3, 1: 4, 2: 5, 3: 6, 4: 7, 5: 8}
final_prediction = np.vectorize(label_map.get)(final_prediction)
print(final_prediction)
# Out:
# [2.57194794e-02 7.73134416e-04 1.74392236e-02 9.80431333e-02
#  7.14580894e-03 2.50426811e-01 7.51026165e-03 4.51345891e-03
#  9.62634826e-02 4.37604335e-02 2.07378597e-02 3.47143910e-02
#  1.57520361e-02 5.12392891e-03 3.23678552e-02 5.32194210e-02
#  1.13731298e-02 1.64439694e-03 2.94065096e-02 2.74373273e-02
#  5.95715129e-03 7.09243692e-03 3.88128242e-02 2.13496057e-01
#  2.69991676e-02 1.08672758e-02 1.79009418e-02 3.63956294e-02
#  4.82192188e-02 2.47320928e-02 1.96246911e-02 2.26456352e-02
#  7.38332918e-02 2.21825683e-03 1.43656566e-02 1.30678264e-02
#  1.60450120e-04 2.46568802e-02 3.96375223e-02 2.38073039e-02
#  2.53200616e-03 7.44396281e-03 4.52478221e-03 2.91563944e-02
#  2.46945045e-02 7.77858468e-04 1.12066456e-02 3.88668687e-02
#  6.41070796e-03 4.51964166e-03 5.72304066e-02 7.45141118e-03
#  1.56540051e-02 2.15144266e-01 2.04090915e-02 4.55709846e-02
#  1.14367187e-02 1.49887487e-02 1.09762824e-02 1.47300407e-02
# ...
